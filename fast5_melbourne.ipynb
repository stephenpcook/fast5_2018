# %%
import pandas as pd

# %%
with open('fast5_melbourne_all.csv','r') as csvfile:
    df = pd.read_csv(csvfile, sep='\t')

# %%
df['shots scored'] = df['G1']+df['G2']+df['G3']

# %%
df['points scored'] = df['G1'] + 2*df['G2'] + 3*df['G3']

# %%
df['shot attempts'] = df['G1A']+df['G2A']+df['G3A']

# %%
df['shot accuracy'] = df['shots scored']*100.0/df['shot attempts']

# %%
df['G1 accuracy'] = df['G1']*100.0/df['G1A']
df['G2 accuracy'] = df['G2']*100.0/df['G2A']
df['G3 accuracy'] = df['G3']*100.0/df['G3A']

# %%
df.sort_values('shot attempts', ascending=False).head(5)
# Out:
#                name  G1  G2  G3  G1A  G2A  G3A Country  shots scored  \
# 16  Georgina Fisher  25  22   5   30   45   15     ENG            52
# 20    Romelda Aiken  63   3   0   65   13    4     JAM            66
# 9    Kaylia Stanton  28  17   3   33   41    7     AUS            48
# 37      Joyce Mvula  48   4   1   56   15    8     MWI            53
# 1      Kiera Austin  25  18   0   26   45    6     AUS            43
#
#     points scored  shot attempts  shot accuracy  G1 accuracy  G2 accuracy  \
# 16             84             90      57.777778    83.333333    48.888889
# 20             69             82      80.487805    96.923077    23.076923
# 9              71             81      59.259259    84.848485    41.463415
# 37             59             79      67.088608    85.714286    26.666667
# 1              61             77      55.844156    96.153846    40.000000
#
#     G3 accuracy
# 16    33.333333
# 20     0.000000
# 9     42.857143
# 37    12.500000
# 1      0.000000

# %%
with open('R1_2.csv','r') as csvfile:
    df2 = pd.read_csv(csvfile, sep=',')
df2.head()
# Out:
#    Quarter  Time    Player    Action  Score
# 0        1  1:21   J.Mvula  3PT MISS  0 - 0
# 1        1  1:44  K.Austin  1PT GOAL  1 - 0
# 2        1  2:19   J.Mvula  1PT GOAL  1 - 1
# 3        1  2:38  S.Garbin  1PT GOAL  2 - 1
# 4        1  3:01  S.Garbin  2PT MISS  2 - 1

# %%
players = df2['Player'].unique()
actions = df2['Action'].unique()

# %%
df3 = pd.DataFrame(players, columns=['player'])
for act in actions:
    df3[act] = 0

# %%
df3 = df3.set_index('player')

# %%
for player in players:
    for action in actions:
        df3.loc[player, action] = len(df2.loc[(df2["Player"]==player) & (df2["Action"]==action)])

# %%
df3.head()
# Out:
#              3PT MISS  1PT GOAL  2PT MISS  2PT GOAL  1PT MISS  1PT GOAL (PP)  \
# player
# J.Mvula             7        35        11         4         8             13
# K.Austin            6        17        27        12         1              8
# S.Garbin            4        13        18        12         2              2
# J.Chimaliro         5         8        11         7         2              0
# K.Stanton           4        19        24        13         5              9
#
#              2PT GOAL (PP)  3PT GOAL  3PT GOAL (PP)
# player
# J.Mvula                  0         0              1
# K.Austin                 6         0              0
# S.Garbin                 1         0              0
# J.Chimaliro              2         2              0
# K.Stanton                4         3              0

# %%
df3['G1'] = df3['1PT GOAL'] + df3['1PT GOAL (PP)']
df3['G2'] = df3['2PT GOAL'] + df3['2PT GOAL (PP)']
df3['G3'] = df3['3PT GOAL'] + df3['3PT GOAL (PP)']

df3['G1A'] = df3['G1'] + df3['1PT MISS']
df3['G2A'] = df3['G2'] + df3['2PT MISS']
df3['G3A'] = df3['G3'] + df3['3PT MISS']

df3['shot attempts'] = df3['G1A'] + df3['G2A'] + df3['G3A']

df3['points (ignore PP)'] = df3['G1'] + 2*df3['G2'] + 3*df3['G3']

df3['points'] = (1*df3['1PT GOAL'] + 2*df3['1PT GOAL (PP)']
                 + 2*df3['2PT GOAL'] + 4*df3['2PT GOAL (PP)']
                 + 3*df3['3PT GOAL'] + 6*df3['3PT GOAL (PP)'])

df3['points per shot'] = df3['points']/df3['shot attempts']

# %%
df3[['G1', 'G2', 'G3', 'G1A', 'G2A', 'G3A', 'shot attempts',
     'points (ignore PP)', 'points', 'points per shot']].sort_values('points per shot', ascending=False)
# Out:
#              G1  G2  G3  G1A  G2A  G3A  shot attempts  points (ignore PP)  \
# player
# S.Beckford    1  11  10    3   22   27             52                  53
# S.Burger     23  22   0   25   43    0             68                  67
# G.Fisher     25  22   5   30   45   15             90                  84
# R.Stoltz      0  27   3    0   56   16             72                  63
# B.Mes        20  15   0   21   33    0             54                  50
# A.Dunn       29  13   2   29   23   10             62                  61
# M.Falkner     8   5   1   10   11    3             24                  21
# T.Harwood     0  11   1    0   20    7             27                  25
# K.Stanton    28  17   3   33   41    7             81                  71
# R.Aiken      63   3   0   65   13    4             82                  69
# K.Austin     25  18   0   26   45    6             77                  61
# J.Mazengera  10   3   0   11   12    0             23                  16
# E.Clark      17   3   1   19    9    5             33                  26
# S.Nelson      8   2   0    9    6    0             15                  12
# J.Chimaliro   8   9   2   10   20    7             37                  32
# J.Mvula      48   4   1   56   15    8             79                  59
# S.Garbin     15  13   0   17   31    4             52                  41
# A.Ekenasio   16   6   0   16   18    9             43                  28
# K.Corbin     14   1   0   15   10    2             27                  16
# D.Lochner     4   0   0    4    3    0              7                   4
# E.Cardwell    3   2   0    6    8    2             16                   7
# A.Kamwala     1   0   0    3    3    2              8                   1
# S.Corbin      0   0   0    0    1    0              1                   0
#
#              points  points per shot
# player
# S.Beckford       68         1.307692
# S.Burger         85         1.250000
# G.Fisher        112         1.244444
# R.Stoltz         87         1.208333
# B.Mes            64         1.185185
# A.Dunn           72         1.161290
# M.Falkner        27         1.125000
# T.Harwood        30         1.111111
# K.Stanton        88         1.086420
# R.Aiken          89         1.085366
# K.Austin         81         1.051948
# J.Mazengera      24         1.043478
# E.Clark          33         1.000000
# S.Nelson         15         1.000000
# J.Chimaliro      36         0.972973
# J.Mvula          75         0.949367
# S.Garbin         45         0.865385
# A.Ekenasio       34         0.790698
# K.Corbin         19         0.703704
# D.Lochner         4         0.571429
# E.Cardwell        7         0.437500
# A.Kamwala         1         0.125000
# S.Corbin          0         0.000000

# %%
df[['name', 'G1', 'G2', 'G3', 'G1A', 'G2A', 'G3A', 'Country', 'shots scored',
    'shot attempts', 'points scored']].sort_values(
    ['points scored', 'shot attempts'], ascending=False).head(23)
#df.sort_values(['points scored', 'shot attempts'], ascending=False).head(23)
# Out:
#                     name  G1  G2  G3  G1A  G2A  G3A Country  shots scored  \
# 16       Georgina Fisher  25  22   5   30   45   15     ENG            52
# 9         Kaylia Stanton  28  17   3   33   41    7     AUS            48
# 20         Romelda Aiken  63   3   0   65   13    4     JAM            66
# 50         Sigrid Burger  23  22   0   25   43    0     ZAF            45
# 57         Renske Stoltz   0  27   3    0   56   16     ZAF            30
# 1           Kiera Austin  25  18   0   26   45    6     AUS            43
# 41           Aliyah Dunn  29  13   2   29   23   10     NZL            44
# 37           Joyce Mvula  48   4   1   56   15    8     MWI            53
# 21      Shanice Beckford   1  11  10    3   22   27     JAM            22
# 47            Bailey Mes  20  15   0   21   33    0     NZL            35
# 2          Sophie Garbin  15  13   0   17   31    4     AUS            28
# 30        Jane Chimaliro   8   9   2   10   20    7     MWI            19
# 42  Ameliaranne Ekenasio  16   6   0   16   18    9     NZL            22
# 12            Ella Clark  17   3   1   19    9    5     ENG            21
# 23     Thristina Harwood   0  11   1    0   20    7     JAM            12
# 43        Monica Falkner   8   5   1   10   11    3     NZL            14
# 13         Kadeen Corbin  14   1   0   15   10    2     ENG            15
# 36      Jessie Mazengera  10   3   0   11   12    0     MWI            13
# 24        Shimona Nelson   8   2   0    9    6    0     JAM            10
# 10      Eleanor Cardwell   3   2   0    6    8    2     ENG             5
# 53       Danelle Lochner   4   0   0    4    3    0     ZAF             4
# 34       Alinafe Kamwala   1   0   0    3    3    2     MWI             1
# 14          Sasha Corbin   0   0   0    0    1    0     ENG             0
#
#     shot attempts  points scored
# 16             90             84
# 9              81             71
# 20             82             69
# 50             68             67
# 57             72             63
# 1              77             61
# 41             62             61
# 37             79             59
# 21             52             53
# 47             54             50
# 2              52             41
# 30             37             32
# 42             43             28
# 12             33             26
# 23             27             25
# 43             24             21
# 13             27             16
# 36             23             16
# 24             15             12
# 10             16              7
# 53              7              4
# 34              8              1
# 14              1              0

# %%
(list(df.sort_values(['points scored', 'shot attempts'], ascending=False).head(23)['shot attempts']) ==
 list(df3.sort_values(['points (ignore PP)', 'shot attempts'], ascending=False)['shot attempts']))
# Out:
# True
